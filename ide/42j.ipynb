# %%
import pandas as pd 
import json
from pprint import pprint # Импортируем функцию pprint()

# %%
data = pd.read_table('https://raw.githubusercontent.com/esabunor/MLWorkspace/master/melb_data.csv', sep=',')
display(data)
# Out:
#        Unnamed: 0        Suburb           Address  Rooms Type      Price
# 0               1    Abbotsford      85 Turner St      2    h  1480000.0  \
# 1               2    Abbotsford   25 Bloomburg St      2    h  1035000.0
# 2               4    Abbotsford      5 Charles St      3    h  1465000.0
# 3               5    Abbotsford  40 Federation La      3    h   850000.0
# 4               6    Abbotsford       55a Park St      4    h  1600000.0
# ...           ...           ...               ...    ...  ...        ...
# 18391       23540  Williamstown   8/2 Thompson St      2    t   622500.0
# 18392       23541  Williamstown      96 Verdon St      4    h  2500000.0
# 18393       23544     Yallambie      17 Amaroo Wy      4    h  1100000.0
# 18394       23545    Yarraville        6 Agnes St      4    h  1285000.0
# 18395       23546    Yarraville     33 Freeman St      4    h  1050000.0
#
#       Method     SellerG        Date  Distance  ...  Bathroom  Car  Landsize
# ...

# %%
data = pd.read_csv('data/students_performance.zip')
display(data)
compression_opts = dict(method='zip', archive_name='out.csv') # Определяем параметры архивирования — метод сжатия, имя файл в архиве
data.to_csv('data/out.zip', index=False, compression=compression_opts)
# Out:
#      gender race/ethnicity parental level of education         lunch
# 0    female        group B           bachelor's degree      standard  \
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
#!pip install openpyxl
# Out:
# ...
# WARNING: You are using pip version 21.2.4; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\Nata\AppData\Local\Programs\Python\Python39\python.exe -m pip install --upgrade pip' command.

# %%
grades = pd.read_excel('data/grades.xlsx')
display(grades.head())

# %%
grades = pd.read_excel('data/grades.xlsx', sheet_name='Maths')
display(grades.head())
# Out:
#    Student ID Student name  Grade
# 0           1          Аня      8
# 1           2         Катя      9
# 2           3         Маша      7
# 3           4         Миша      4
# 4           5         Женя      8

# %%
movies = pd.read_excel('data/ratings+movies.xlsx', sheet_name='movies')
ratings = pd.read_excel('data/ratings+movies.xlsx', sheet_name='ratings')
ratings_w_movie_info = pd.merge(ratings, movies, on='movieId', how='left')
display(ratings_w_movie_info)
# Out:
#         userId  movieId  rating   timestamp                           title
# 0            1        1     4.0   964982703                Toy Story (1995)  \
# 1            1        3     4.0   964981247         Grumpier Old Men (1995)
# 2            1        6     4.0   964982224                     Heat (1995)
# 3            1       47     5.0   964983815     Seven (a.k.a. Se7en) (1995)
# 4            1       50     5.0   964982931      Usual Suspects, The (1995)
# ...        ...      ...     ...         ...                             ...
# 100831     610   166534     4.0  1493848402                    Split (2017)
# 100832     610   168248     5.0  1493850091   John Wick: Chapter Two (2017)
# 100833     610   168250     5.0  1494273047                  Get Out (2017)
# 100834     610   168252     5.0  1493846352                    Logan (2017)
# 100835     610   170875     3.0  1493846415  The Fate of the Furious (2017)
#
#                                              genres
# ...

# %%
import pandas as pd # Импортируем модуль pandas
df = pd.read_json('data/recipes.json') # Создаём объект DataFrame, загружая содержимое файла recipes.json
display(df) # Выводим на экран первые строки полученного DataFrame
# Out:
#         id      cuisine                                        ingredients
# 0    10259        greek  [romaine lettuce, black olives, grape tomatoes...
# 1    25693  southern_us  [plain flour, ground pepper, salt, tomatoes, g...
# 2    20130     filipino  [eggs, pepper, salt, mayonaise, cooking oil, g...
# 3    22213       indian                [water, vegetable oil, wheat, salt]
# 4    13162       indian  [black pepper, shallots, cornflour, cayenne pe...
# ..     ...          ...                                                ...
# 495   1121      chinese  [ground pepper, garlic, safflower oil, green o...
# 496  18376      italian  [penne, garlic, eggplant, lemon juice, olive o...
# 497  17815      italian  [cold water, dry white wine, fish fillets, cho...
# 498  32878  southern_us  [water, cajun seasoning, yellow onion, shrimp,...
# 499  24410      british  [mint, large eggs, heavy cream, berries, groun...
#
# [500 rows x 3 columns]

# %%
with open("data/recipes.json") as f:  # Открываем файл и связываем его с объектом "f"
    recipes = json.load(f)  # Загружаем содержимое открытого файла в переменную recipes

#pprint(recipes) # Выводим на экран содержимое переменной recipes, используя функцию pprint()
cuisine_set = set()
cuisine_dict = dict()
ingrid_set = set()
for rec in recipes:
     cuisine_set.add(rec['cuisine'])
     
for cus in cuisine_set:
    cuisine_dict[cus] = 0
    for rec in recipes:
        if rec['cuisine'] == cus:
            cuisine_dict[cus] += 1
            
def contains(ingredient_list): # Определяем имя функции и передаваемые аргументы
    if ingredient_name in ingredient_list: # Если ингредиент есть в текущем блюде,
        return 1 # возвращаем значение 1
    else: # Если ингредиента нет в текущем блюде,
        return 0 # возвращаем значение 0
    
for rec in recipes:
    for ingridient in rec['ingredients']:
        ingrid_set.add(ingridient)
     
display(len(ingrid_set))
df = pd.DataFrame(recipes)

for ingredient_name in ingrid_set: # Последовательно перебираем ингредиенты в реестре all_ingredients
    df[ingredient_name] = df['ingredients'].apply(contains) # В DataFrame cоздаём столбец с именем текущего ингредиента и заполняем его единицами и нулями, используя ранее созданную функцию contains
df.ingredients = df.ingredients.apply(lambda x: len(list(x)))
print(df.info()) # Выводим на экран первые строки полученного DataFrame
df.to_csv('recipes.csv', index = False)
# Out:
# 1318
# C:\Users\Nata\AppData\Local\Temp\ipykernel_1424\4092276380.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   df[ingredient_name] = df['ingredients'].apply(contains) # В DataFrame cоздаём столбец с именем текущего ингредиента и заполняем его единицами и нулями, используя ранее созданную функцию contains
# C:\Users\Nata\AppData\Local\Temp\ipykernel_1424\4092276380.py:31: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
# ...

# %%
recipes_df_csv = pd.read_csv('recipes.csv', sep = ',')
recipes_id_list = list(recipes_df_csv.id)

ingredients_list = list(recipes_df_csv.columns[3:])

def make_list(df_row):
    result_list = list()
    for ingrid in ingredients_list:
        if df_row.loc[ingrid] == 1:
            result_list.append(ingrid)
    return result_list

new_recipes = [] # Создаём пустой список для хранения итоговой структуры
for current_id in recipes_id_list[:2]: # Организуем цикл с параметром current_id
    cuisine = recipes_df_csv[recipes_df_csv['id'] == current_id]['cuisine'].iloc[0] # Получаем значение соответствующей кухни, применив фильтр по текущему значению параметра цикла к DataFrame;
    current_ingredients = make_list(df_row=recipes_df_csv[recipes_df_csv['id'] == current_id].iloc[1,]) # Получаем перечень ингредиентов, входящих в состав текущего блюда
    current_recipe = {'cuisine': cuisine, 'id': int(current_id), 'ingredients': current_ingredients} # Создаём текущий словарь
    new_recipes.append(current_recipe) # Добавляем созданный словарь к списку

display(new_recipes)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[11], line 16
#      14 for current_id in recipes_id_list[:2]: # Организуем цикл с параметром current_id
#      15     cuisine = recipes_df_csv[recipes_df_csv['id'] == current_id]['cuisine'].iloc[0] # Получаем значение соответствующей кухни, применив фильтр по текущему значению параметра цикла к DataFrame;
# ---> 16     current_ingredients = make_list(df_row=recipes_df_csv[recipes_df_csv['id'] == current_id].iloc[1,]) # Получаем перечень ингредиентов, входящих в состав текущего блюда
#      17     current_recipe = {'cuisine': cuisine, 'id': int(current_id), 'ingredients': current_ingredients} # Создаём текущий словарь
#      18     new_recipes.append(current_recipe) # Добавляем созданный словарь к списку
#
# ...
